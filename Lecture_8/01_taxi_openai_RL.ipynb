# %% [markdown]
# # GYM Taxi environment with Q-learning
#
# **Description:** Simple Q-learning using taxi environment GYM time<br>
# There are 4 locations objective is to pick passenger at one location and drop him off in another.<br>
# Penalties: -1 for each timestep, -10 for illegal dropoff/pickup<br>
# Bonus: +20 for each dropoff<br>
# https://gym.openai.com/envs/Taxi-v2/

# %%
import gym
from IPython.display import clear_output
from time import sleep
import numpy as np
import random

# %%
# supporting functions
def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'])
        print(f"Timestep: {i + 1}")
        print(f"State: {frame['state']}")
        print(f"Action: {frame['action']}")
        print(f"Reward: {frame['reward']}")
        sleep(.1)

# %%
env = gym.make("Taxi-v3").env
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.reset() # reset environment to a new, random state
env.render()

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# Action Space Discrete(6)
# State Space Discrete(500)

# %% [markdown]
# #### Solve enviroment without reinforcement
# (using a q-table)

# %%
env.s = 328  # set environment to illustration's state

epochs = 0
penalties, reward = 0, 0

frames = [] # for animation

done = False

while not done:
    action = env.action_space.sample()
    print('action:',action)
    state, reward, done, info = env.step(action)
    print('action:',action, '->', state,reward,done,info)

    if reward == -10:
        penalties += 1
    
    # Put each rendered frame into dict for animation
    frames.append({
        'frame': env.render(mode='ansi'),
        'state': state,
        'action': action,
        'reward': reward
        }
    )

    epochs += 1
       
print("Timesteps taken (epochs): {}".format(epochs))
print("Penalties incurred: {}".format(penalties))
# Out:
# action: 5
# action: 5 -> 328 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 328 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 428 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 428 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 428 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 328 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 448 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 448 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 448 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 428 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 448 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 348 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 348 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 248 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 248 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 248 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 148 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 148 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 168 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 168 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 168 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 168 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 188 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 88 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 88 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 68 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 68 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 88 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 88 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 188 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 188 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 188 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 168 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 148 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 148 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 148 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 148 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 148 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 168 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 168 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 168 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 68 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 68 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 48 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 148 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 48 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 48 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 148 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 168 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 188 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 188 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 168 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 68 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 68 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 68 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 48 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 48 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 48 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 48 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 148 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 168 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 68 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 88 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 88 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 88 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 88 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 68 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 168 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 148 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 248 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 248 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 228 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 228 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 208 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 308 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 308 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 408 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 416 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 416 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 416 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 416 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 416 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 416 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 416 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 416 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 316 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 316 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 316 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 416 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 408 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 408 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 308 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 208 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 208 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 308 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 208 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 308 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 208 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 208 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 208 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 228 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 328 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 328 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 328 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 348 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 448 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 448 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 428 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 428 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 428 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 328 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 328 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 328 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 328 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 328 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 228 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 208 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 208 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 208 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 228 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 228 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 228 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 248 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 248 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 148 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 148 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 148 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 148 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 148 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 48 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 48 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 48 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 68 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 88 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 88 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 88 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 88 -10 False {'prob': 1.0}
# action: 5
# action: 5 -> 88 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 88 -10 False {'prob': 1.0}
# action: 0
# action: 0 -> 188 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 188 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 188 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 188 -10 False {'prob': 1.0}
# action: 2
# action: 2 -> 188 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 168 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 168 -10 False {'prob': 1.0}
# action: 2
# action: 2 ->
-1 False {'prob': 1.0}
# action: 5
# action: 5 -> 196 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 176 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 176 -10 False {'prob': 1.0}
# action: 4
# action: 4 -> 176 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 156 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 256 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 356 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 356 -1 False {'prob': 1.0}
# action: 4
# action: 4 -> 356 -10 False {'prob': 1.0}
# action: 3
# action: 3 -> 336 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 436 -1 False {'prob': 1.0}
# action: 0
# action: 0 -> 436 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 436 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 336 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 236 -1 False {'prob': 1.0}
# action: 1
# action: 1 -> 136 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 136 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 136 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 136 -10 False {'prob': 1.0}
# action: 1
# action: 1 -> 36 -1 False {'prob': 1.0}
# action: 2
# action: 2 -> 36 -1 False {'prob': 1.0}
# action: 3
# action: 3 -> 16 -1 False {'prob': 1.0}
# action: 5
# action: 5 -> 0 20 True {'prob': 1.0}
# Timesteps taken (epochs): 7536
# Penalties incurred: 2544

# %%
print_frames(frames)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Timestep: 7536
# State: 0
# Action: 5
# Reward: 20

# %% [markdown]
# #### Using Q-learning to train via reinforcement
# (using Q-learning)

# %%
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# %%
# %%time
# Training the agent

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1

# For plotting metrics
all_epochs = []
all_penalties = []

for i in range(1, 100001):
    state = env.reset()

    epochs, penalties, reward, = 0, 0, 0
    done = False
    
    while not done:
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample() # Explore action space
        else:
            action = np.argmax(q_table[state]) # Exploit learned values

        next_state, reward, done, info = env.step(action) 
        
        old_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value

        if reward == -10:
            penalties += 1

        state = next_state
        epochs += 1
        
    if i % 100 == 0:
        clear_output(wait=True)
        print(f"Episode: {i}")

print("Training finished.\n")
# Out:
# Episode: 100000
# Training finished.
#
# CPU times: user 48.9 s, sys: 12.3 s, total: 1min 1s
# Wall time: 46 s

# %% [markdown]
# #### Evaluate agent

# %%
# Evaluate agent's performance after Q-learning
frames = []

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    state = env.reset()
    epochs, penalties, reward = 0, 0, 0
    
    done = False
    
    while not done:
        action = np.argmax(q_table[state])
        state, reward, done, info = env.step(action)
        # Put each rendered frame into dict for animation
        frames.append({
           'frame': env.render(mode='ansi'),
           'state': state,
           'action': action,
           'reward': reward
        }
        )

        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")
# Out:
# Results after 100 episodes:
# Average timesteps per episode: 13.39
# Average penalties per episode: 0.0

# %%
print_frames(frames)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Timestep: 1339
# State: 410
# Action: 5
# Reward: 20
